# %% [markdown]
# # Step 3-4: Load Raw Data & Data Quality Analysis
# Cart2Insights Project

# %%
import sys
sys.path.append('../streamlit')

from utils import load_all_csvs, inspect_all, check_pk_uniqueness

dfs = load_all_csvs('../data/raw/')
print('Tables loaded:', list(dfs.keys()))

# %%
inspect_all(dfs)

# %% [markdown]
# ## Primary Key Uniqueness Checks
# Fill in the actual PK column name per table once schema is confirmed.

# %%
# Example — update table/column names to match your actual dataset:
# check_pk_uniqueness(dfs['orders'], 'order_id', 'orders')
# check_pk_uniqueness(dfs['customers'], 'customer_id', 'customers')
